# %% [markdown]
# &copy; 2024 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com
#
# <hr/>

# %%
# %%html
# <style>
#     h1 {color:#BB0000}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>
# Out:
# <style>
#     h1 {color:#BB0000}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>

# %%
# enable high-res images in notebook 
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # What is Generative AI?
# * AI that creates content
#     * Text, images, audio, video, music, poetry, code, ...
#     * Makes content creation accessible to everyone
# * Can be tailored to specific requirements
# * References
#     * https://en.wikipedia.org/wiki/Generative_artificial_intelligence
#     * https://www.techtarget.com/searchenterpriseai/definition/generative-AI
#     * https://www.mckinsey.com/featured-insights/mckinsey-explainers/what-is-generative-ai

# %% [markdown]
# <hr/>

# %% [markdown]
# # What is a Large Language Model (LLM)?
# * AI that understands/generates natural language
# * "Large" — Neural nets with **billions**, and now **trillions**, of parameters
#     * As neural nets learn, they tune parameters in an effort to produce better results
#     * Parameters helps models understand/generate language patterns
# * Trained on massive amounts of text
#     * books, articles, the Internet, code, ...
# * Great at natural language tasks
#     * Translation, summarization, answering questions, sentiment analysis, creative writing, ...
#     * Also generating code, explaining code, finding errors in code, ...
# * Can generate text indistinguishable from human writing
# * Some continue to learn and adapt, improving effectiveness over time
# * Many LLMs use **generative pretrained transformers (GPTs)**
# * References
#     * https://en.wikipedia.org/wiki/Large_language_model
#     * https://www.techtarget.com/whatis/definition/large-language-model-LLM
#     * https://machinelearningmastery.com/what-are-large-language-models/
# * There are other techniques, like **Bidirectional Encoder Representations from Transformers (BERT)**
#     * https://en.wikipedia.org/wiki/BERT_(language_model)

# %% [markdown]
# <hr/>

# %% [markdown]
# # What is a Transformer?
# * Neural network that processes sequential data, like text
# * Can understand/recognize relationships between distant words in a sentence
# * Also recognizes the relative importance of words
# * References for Transformers
#     * https://en.wikipedia.org/wiki/Transformer_(machine_learning_model)
#     * https://blogs.nvidia.com/blog/what-is-a-transformer-model/
#     * https://towardsdatascience.com/transformers-141e32e69591

# %% [markdown]
# <hr/>

# %% [markdown]
# # What is a Self-Attention?
# * Key aspect of transformers
# * When you try to understand a word in a sentence, words around it (its context) can help you understand the meaning
#     * "good" is positive, but preceding it with "not" makes the context negative
# * Transformers use self-attention to understand each word by looking at other words around it
#     * Words are not equally important
#     * Self-attention weighs which words to pay attention to when trying to understand each word
# * Unlike humans, transformers can consider massive numbers of words in parallel to understand how words are connected
# * References for Self-Attention
#     * https://towardsdatascience.com/illustrated-self-attention-2d627e33b20a
#     * https://en.wikipedia.org/wiki/Attention_(machine_learning)

# %% [markdown]
# <hr/>

# %% [markdown]
# # Tokens, Context and Context Windows
# * Token
#     * Unit of processing in language models
#     * Words, parts of words, punctuation
#     * Tokenization converts tokens to numerical values models can process
#     * Models typically have token limits
# * Context
#     * Sequence of tokens that comes before (and sometimes after) a word/phrase
#     * Understanding context helps models generate more accurate responses
# * Context window
#     * Maximum range of tokens (both input and output) model can consider at once
#     * Larger == more context to the conversation == more relevant/coherent responses
#     * Google Gemini 1 million tokens
#     > https://blog.google/technology/ai/google-gemini-next-generation-model-february-2024/#context-window
#     * Claude.ai Pro 200K tokens
#     > https://blog.google/technology/ai/google-gemini-next-generation-model-february-2024/#context-window
#     * GPT-4 Turbo (OpenAI) 128K tokens
#     > https://platform.openai.com/docs/models/overview

# %% [markdown]
# <hr/>

# %% [markdown]
# # Prompts and Prompt Engineering
# * Poor prompts, lead to poor results — "garbage in, garbage out"
# * Prompt engineering is the process of desining prompts to obtain the best responses
# * OpenAI provides various strategies
#     * https://platform.openai.com/docs/guides/prompt-engineering

# %% [markdown]
# <hr/>

# %% [markdown]
# # Issues with Generative AI
# * Ethics — e.g., misinformation, realistic images/videos
# * Biases
# * **Hallucinations** — They sometime make up facts
# * Copyrights
#     * NYT Sues OpenAI: https://www.nytimes.com/2023/12/27/business/media/new-york-times-open-ai-microsoft-lawsuit.html
# * Picks up human traits?
#     * ChatGPT gets lazy (“winter break hypothesis”): https://arstechnica.com/information-technology/2023/12/is-chatgpt-becoming-lazier-because-its-december-people-run-tests-to-find-out/)
# * ...

# %% [markdown]
# <hr/>

# %% [markdown]
# # OpenAI
# * https://openai.com/
# * One of many generative AI providers
# * Creator of ChatGPT, Dall-E
# * APIs for
#     * Audio — speech-to-text, text-to-speech, translation
#     * Chat (ChatGPT)
#     * Fine - tuning—tailoring to your own data
#     * Images (Dall-E)
#     * Models — explains all the available models
#     * Moderations — checks content policy violations
#     * Assistants — create assitants that can perform step-by-step tasks
#     * more...
# * OpenAI Cookbook — loaded with examples: https://cookbook.openai.com/
# * OpenAI Docs — tutorials, guides, ...: https://platform.openai.com/docs/overview
# * OpenAI API Reference: https://platform.openai.com/docs/api-reference

# %% [markdown]
# <hr/>

# %% [markdown]
# # Installing the OpenAI Python Module
# * `pip install --upgrade openai`

# %% [markdown]
# <hr/>

# %% [markdown]
# # Get an OpenAI Developer Account
# * Signup: https://platform.openai.com/signup
# * Pricing — small free credit depending on location
# > https://openai.com/pricing
# * Rate Limits
# > https://platform.openai.com/docs/guides/rate-limits/rate-limits

# %% [markdown]
# <hr/>

# %% [markdown]
# ## OpenAI Developer API Key
# * While signed into your account
#     * Go to https://platform.openai.com/docs/overview
#     * Hover over the icons at the left of the page and click the **API keys** icon (looks like a padlock)
#     * Click **Create new secret key**
#     * Optionally name your key
#     * Click **Create secret key**
#     * Copy the lengthy alphanumeric key
#     * Follow instructions for your platform at https://platform.openai.com/docs/quickstart to store the API key in an environment variable
#     * **Restart your command line before launching iPython or Jupyter Lab**

# %% [markdown]
# <hr/>

# %% [markdown]
# # Some of OpenAIs Models with APIs

# %% [markdown]
# | MODEL | DESCRIPTION |
# |-------|-------------|
# | GPT-4o | Current high-intelligence model. Can handle complex, multi-step tasks. |
# | GPT-4o mini | Smaller, more affordable model than the flagship GPT-4o model. Meant for fast, lightweight tasks. |
# | GPT-4 & GPT-4 Turbo | Latest models. Understand/generate natural language or code. |
# | GPT-3.5 | Previous models. Understand/generate natural language or code. |
# | DALL·E | Generates/edits images in response to natural language prompts. |
# | TTS | Converts text to speech. |
# | Whisper | Transcribes and translates audio. |
# | Embeddings | Converts text into numerical form. |
# | Moderation | Detects sensitive/unsafe text. |

# %% [markdown]
# <hr/>

# %% [markdown]
# # Speech-to-Text, Text-to-Speech, Language Translation
# * Based on OpenAI's tutorial: Creating an automated meeting minutes generator with Whisper and GPT-4
# > https://platform.openai.com/docs/tutorials/meeting-minutes

# %% [markdown]
# ## Importing the Modules for This Demo

# %%
from openai import OpenAI 
# from docx import Document # for creating a Microsoft Word docx file

# %% [markdown]
# ## Creating the `OpenAI` Client Object
# * Provides access to the OpenAI APIs

# %%
client = OpenAI()

# %% [markdown]
# * Assumes your API key is in the environment variable `OPENAI_API_KEY`
# * If you used a different environment variable name, replace with preceding statement with
# > `client = OpenAI(api_key=os.environ.get("CUSTOM_ENV_NAME"))`

# %% [markdown]
# ## `speech_to_text` Function
# * Opens file at `audio_path` for reading in binary mode (`'rb'`)
# * Calls OpenAI `client` object's `audio.transcriptions.create` method
#     * passes `audio_file` to OpenAI's `whisper-1` model to create transcript

# %%
def speech_to_text(audio_path):
    with open(audio_path, 'rb') as audio_file:
        transcript = client.audio.transcriptions.create(
            model='whisper-1', file=audio_file)
    return transcript.text

# %%
transcript = speech_to_text('deep_learning_intro.m4a')

# %%
transcript
# Out:
# "So let's start with a little bit of an introduction to deep learning, which is a powerful subset of the machine learning capabilities that are available to us, not only in Python, but in other languages as well. Now, deep learning is particularly resource intensive because of the approach that it takes, but as you're about to see, whether you're a professional just getting into deep learning for the first time, or even a novice programmer, the libraries that we use, once again, are going to make it possible for us to start working with these supremely complex models behind the scenes. And one of the reasons that we're able to do that is because of the availability of things like big data, lots of processing power, whether it's on even our desktop computers, but mostly in the cloud nowadays, faster internet speeds to help us work with those processors and data in the cloud, and separately, advancements in parallel computing, both at the hardware and software levels. Now, the models that we're going to build in this lesson are much more sophisticated in terms of their setups and what's going on behind the scenes than the scikit-learn models that we started looking at in the preceding lesson. Typically, we're going to build our models by connecting together many layers, and one of the reasons it's called deep learning is that the more layers you have, the deeper the stack of layers is, and that's where the term deep learning comes from. Now, we'll be, again, working with this library called Keras, which is a friendly interface to the most popular of the deep learning libraries out there, Google's TensorFlow, and that is by far the most widely used of the deep learning libraries. But Keras was developed by a gentleman by the name of Francois Chollet from the Google Mind team, and his goal with Keras was to make deep learning easier and more accessible to everyone. So, if you are interested after looking through this lesson in pursuing deep learning more, I would highly recommend his book called Deep Learning with Python as well. And, by the way, Google alone has thousands of TensorFlow and Keras deep learning projects going on internally at the moment, and yearly, that number is increasing very quickly as well. Now, again, the deep learning models that we're going to be looking at are extremely complex. They require extensive mathematical backgrounds to understand their inner workings. We're not going to focus on mathematics at all in this presentation. Our goal is to show you how we can use Keras similarly to Scikit-learn, but in the context of deep learning. And what you're going to see is that the models we build are going to encapsulate all of that sophisticated mathematics that's going on behind the scenes. So, you will be able to build your own deep learning models even without understanding that mathematics. And, in fact, a little bit later on, I'm going to show you a quote from Francois Chollet about the fact that humans shouldn't be expected to understand the inner workings of certain aspects of these models because they are so complex. And if you think about it, you, on a daily basis as a programmer, are constantly relying on the work of other people to help you build applications, and you do it without questioning how those libraries that you're working with are constructed behind the scenes in most cases. So, the same thing is going on here. It's just a much more complex set of capabilities that are being implemented for you. And, really, you are standing on the shoulders of giants who have come before you to implement these incredibly complex model capabilities and allow you, as a programmer, to take advantage of them in your daily programming tasks. Now, the deep learning stuff that we're going to be doing does require significant processing power. The two examples we will present in this lesson, one of them takes five to six minutes on most of today's computers to train based on the 70,000 images that we'll be work ...

# %% [markdown]
# ## `create_abstract` Function
# * `chat.completions.create` method responds to prompts, similar to interacting directly with ChatGPT through its web interface
# * `model` specifies OpenAI model that will formulate a response
# * Each item in `messages` list is a dictionary containing two keys
#     * `role`: `system`, `user` or `assistant`
#     * `content`: Prompt passed to the OpenAI model
# * Use `role`: `system` when prompting the model with details to help it perform a task
# * Use `role`: `user` when prompting for the task to perform
# * For more details about the message formats: https://cookbook.openai.com/examples/how_to_format_inputs_to_chatgpt_models

# %%
def create_abstract(transcript):
    response = client.chat.completions.create(
        model='gpt-4o-2024-08-06',
        messages=[
            {'role': 'system',
             'content': """Given the following transcript of a 
                 technical presentation, create a summary abstract 
                 that is concise, clear, and written in a direct 
                 style suitable for a 10th-grade reading level. 
                 Focus on the key points of the presentation without 
                 referring to the speaker. Avoid using prepositional 
                 phrases and unnecessary words. Aim for straightforward 
                 sentence structures. Capture the presentation's 
                 essence, enabling a person to understand the presentation 
                 without having to read the full transcript. Format the 
                 abstract in a single, well-structured paragraph."""},
            {'role': 'user',
             'content': transcript}
        ]
    )
    return response.choices[0].message.content
    # Old way to get content--OpenAI tutorial is not yet up to date:
    # return response['choices'][0]['message']['content']

# %%
summary = create_abstract(transcript)

# %%
summary
# Out:
# 'Deep learning is an advanced subset of machine learning, heavily reliant on resources such as big data and powerful computing systems, often leveraging the cloud. It involves building complex models with many layers, hence the term "deep learning." These models are implemented using frameworks like Keras, which simplifies the usage of TensorFlow, a widely-used deep learning library developed by Google\'s team. Keras aims to make deep learning accessible to programmers without needing a deep understanding of the complex mathematics involved. The models can be trained on datasets like MNIST, although this can be time-consuming depending on the available computing power. Training on standard computers can take minutes to hours, but more powerful cloud resources may be required for larger datasets. AutoML tools like AutoKeras are emerging, which aim to automate model creation and tuning, further simplifying the deep learning process. Although deep learning requires significant data preparation and processing power, tools like Keras make it feasible for programmers to build and use sophisticated models without delving into their intricacies.'

# %% [markdown]
# ## `get_key_points` Function
# * Prompt explains how GPT-4 should extract transcript's key points

# %%
def get_key_points(transcript):
    response = client.chat.completions.create(
        model="gpt-4o-2024-08-06",
        messages=[
            {'role': 'system',
             'content' : """Given the following transcript of a 
                 technical presentation, identify and list the 
                 presentation's key points. Keep your writing 
                 concise, direct, and suitable for a 10th grade 
                 reading level. Avoid unnecessary words and excessive 
                 use of prepositional phrases. Aim for clear, 
                 straightforward sentence structures. Present this 
                 information as a numbered list, each point summarizing 
                 a separate key aspect of the presentation."""},
            {'role': 'user',
             'content': transcript}
        ]
    )
    #return response['choices'][0]['message']['content']
    return response.choices[0].message.content

# %%
key_points = get_key_points(transcript)
print(key_points)
# Out:
# 1. Deep learning is a resource-intensive subset of machine learning used in various programming languages, especially Python.
#
# 2. Libraries like Keras and TensorFlow simplify working with complex deep learning models, even for beginners.
#
# 3. The term "deep learning" refers to models with many layers, making them "deep."
#
# 4. Keras, developed by Francois Chollet, aims to make deep learning more accessible to everyone.
#
# 5. Deep learning models involve complex mathematics, but tools like Keras allow model building without deep mathematical knowledge.
#
# 6. Training deep learning models requires significant processing power, potentially taking minutes to hours depending on the computer's capabilities.
#
# 7. Keras includes several datasets, but more data preparation is required compared to using scikit-learn.
#
# 8. Automated deep learning tools, like AutoKeras and Google's AutoML, are developing to simplify model tuning and construction.

# %% [markdown]
# ## `analyze_sentiment` Function
# * Prompt explains how GPT-4 should analyze transcript's sentiment

# %%
def analyze_sentiment(transcript):
    response = client.chat.completions.create(
        model='gpt-4o-2024-08-06',
        messages=[
            {'role': 'system',
             'content': """You are an expert in sentiment analysis. 
                 Analyze the following presentation transcript, then 
                 explain whether the sentiment is positive, negative, 
                 or neutral. Explain your analysis."""},
            {'role': 'user',
             'content': transcript}
        ]
    )
    return response.choices[0].message.content

# %%
sentiment = analyze_sentiment(transcript)
print(sentiment)
# Out:
# The sentiment of the presentation transcript is primarily neutral with a leaning towards positive. Here's the breakdown of the analysis:
#
# 1. **Neutral Tone**: The speaker is primarily focused on delivering information about deep learning, its resources, and tools such as Keras and TensorFlow. The presentation covers technical aspects and details about deep learning processes, requirements, and future possibilities without showing emotional bias.
#
# 2. **Informative and Factual**: The content is educational, aimed at informing the audience about the complexities and potential of deep learning. It remains objective, sticking to explanations and facts, and does not include personal opinions or emotional language that might dictate a strong positive or negative sentiment.
#
# 3. **Positive Lean**: The speaker emphasizes accessibility, advancements in technology, and the availability of resources that make deep learning more approachable for both professionals and novices. This aspect provides a slight positive sentiment, as there is a subtle encouragement to explore deep learning confidently.
#
# Overall, the transcript serves as a detailed and informative introduction to deep learning, conveying credentials of the technology and its ecosystem without emotionally charged language. The slight positive undertones are present due to the encouragement and opportunities highlighted for learners and professionals in the field.

# %% [markdown]
# ## `save_as_docx` Function
# * Saves a dictionary of key-value pairs in `docx` format
#     * Used by Microsoft Word
#     * Supported by other word processors like Google Docs
# * Document headings are keys in `data_dict`
#     * Output as level 1 heading
# * Document contents are output as paragraphs

# %%
def save_as_docx(data_dict, filename):
    document = Document() 
    
    for heading, content in data_dict.items():
        document.add_heading(heading, level=1)
        document.add_paragraph(content)
        
    document.save(filename)

# %%
data_dict = {
    'Presentation Overview': summary,
    'Key Points': key_points,
    'Sentiment Analysis': sentiment
}

# %%
save_as_docx(data_dict, 'presentation_summary.docx')

# %% [markdown]
# ## `text_to_speech` Function
# * Synthesizes speech using OpenAI Audio API
# * Model `'tts-1-hd'` supports 6 voices and 57 languages
#     * Voices optimized for English, but can speak other languages
# * Supports streaming audio with chunk transfer encoding
# * MP3 is default format
#     * Also supports Opus (Internet streaming), AAC (compressed), FLAC (lossless)
# * Can't control emotion (yet)
# > "There is no direct mechanism to control the emotional output of the audio generated. Certain factors may influence the output audio like capitalization or grammar but our internal tests with these have yielded mixed results." (https://platform.openai.com/docs/guides/text-to-speech/faq)
# * For more info, see **Text to speech** guide:
# > https://platform.openai.com/docs/guides/text-to-speech/voice-options

# %%
def text_to_speech(text, filename):
    response = client.audio.speech.create(
        model='tts-1-hd',
        voice='onyx',
        input=text
    )

    response.stream_to_file(f'{filename}.mp3')

# %%
text_to_speech(summary, 'english_summary')
# Out:
# /var/folders/84/stqwg9dd1gb8dy9dxp_4j82r0000gn/T/ipykernel_14685/1499369073.py:8: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(f'{filename}.mp3')

# %% [markdown]
# Discussion of fixing this DeprecationWarning: https://github.com/openai/openai-python/issues/864

# %% [markdown]
# * `IPython` module provides various utilities, including an audio player

# %%
import IPython
IPython.display.Audio('english_summary.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # `translate` Function
# * Text translation via chat completion
# * `system` role's `content` prompt tells chat completion how to operate

# %%
def translate(text, language):
    response = client.chat.completions.create(
        model='gpt-4o-2024-08-06',
        messages=[
            {'role': 'system',
             'content': f"""You are an expert in natural language translation.
                 Translate the following text into {language}."""},
            {'role': 'user',
             'content': text}
        ]
    )
    #return response['choices'][0]['message']['content']
    return response.choices[0].message.content

# %% [markdown]
# ## Text to Translate

# %%
text = 'Today is a beautiful day! Tomorrow looks like bad weather.'

# %% [markdown]
# ## Translate to Spanish
# * Automatically figures out source language

# %%
spanish_text = translate(text, 'Spanish')
spanish_text
# Out:
# '¡Hoy es un día hermoso! Parece que mañana habrá mal tiempo.'

# %%
chinese_text = translate(text, 'Chinese')
chinese_text
# Out:
# '今天是美好的一天！明天的天气看起来不太好。'

# %%
text_to_speech(spanish_text, 'Spanish')
# Out:
# /var/folders/84/stqwg9dd1gb8dy9dxp_4j82r0000gn/T/ipykernel_14685/1499369073.py:8: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(f'{filename}.mp3')

# %%
IPython.display.Audio('Spanish.mp3')

# %%
text_to_speech(chinese_text, 'Chinese')

# %%
IPython.display.Audio('Chinese.mp3')

# %% [markdown]
# <hr/>

# %% [markdown]
# # Generating Python Code with the Chat Completions API

# %%
response = client.chat.completions.create(
    model='gpt-4o-2024-08-06',
    messages=[
        {'role': 'system', 
         'content': 'You are an expert Python programmer.'},
        {'role': 'user', 
         'content': """Write Python code that uses the word_cloud 
             Python library to generate a 1000 pixel by 1000 pixel 
             rainbow color word cloud from the top 200 words in the 
             file 'RomeoAndJuliet.txt' which is in the current folder. 
             Remove both modern English and old English stop words. 
             Use the mask image named mask_heart.png, which is also in 
             the current folder. Display the generated word cloud."""}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# To generate a rainbow-colored word cloud using the word_cloud library while removing both modern and old English stop words, follow these steps. First, ensure you have the necessary resources: `wordcloud` library, `matplotlib` for displaying the image, and an image processing library like `PIL` for handling the mask. Additionally, you'll need lists of stop words for both modern and old English.
#
# Here is the complete Python code:
#
# ```python
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud, STOPWORDS
# from PIL import Image
# import numpy as np
#
# # Load modern and old English stop words
# modern_stopwords = set(STOPWORDS)
# old_english_stopwords = set([
#     "thou", "thee", "thy", "thine", "ye", "canst", "wilt",
#     "hast", "hath", "dost", "doth", "art", "shalt", "shouldst",
#     "wouldst", "couldst", "mayest", "mightest", "mustest"
# ])
#
# # Combine both sets of stop words
# combined_stopwords = modern_stopwords.union(old_english_stopwords)
#
# # Read the entire text
# with open('RomeoAndJuliet.txt', 'r', encoding='utf-8') as file:
#     text = file.read()
#
# # Load the mask image
# mask = np.array(Image.open('mask_heart.png'))
#
# # Configure and generate the word cloud
# wordcloud = WordCloud(
#     width=1000,
#     height=1000,
#     background_color='white',
#     mask=mask,
#     stopwords=combined_stopwords,
#     max_words=200,
#     colormap='rainbow'
# ).generate(text)
#
# # Display the generated word cloud
# plt.figure(figsize=(10, 10), facecolor='k')
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis('off')
# plt.show()
# ```
#
# ### Key Points:
# - **Stop Words**: We combined modern stop words provided by the `wordcloud` library with a custom set of old English stop words.
# - **Mask Image**: A heart-shaped mask is used. Ensure `mask_heart.png` is present in the current directory.
# - **Configuration**: The word cloud is specified to be 1000x1000 pixels, with a rainbow color map and a maximum of 200 words.
# - **Display**: The word cloud is displayed using `matplotlib`.
#
# ### Installation:
# To run the code, you need to install the required libraries if they are not already available:
#
# ```bash
# pip install wordcloud matplotlib pillow
# ```
#
# Make sure that the required files `RomeoAndJuliet.txt` and `mask_heart.png` are present in the current directory. Adjust the set of old English stop words as needed for your specific project.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np

# Load modern and old English stop words
modern_stopwords = set(STOPWORDS)
old_english_stopwords = set([
    "thou", "thee", "thy", "thine", "ye", "canst", "wilt", 
    "hast", "hath", "dost", "doth", "art", "shalt", "shouldst", 
    "wouldst", "couldst", "mayest", "mightest", "mustest"
])

# Combine both sets of stop words
combined_stopwords = modern_stopwords.union(old_english_stopwords)

# Read the entire text
with open('RomeoAndJuliet.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Load the mask image
mask = np.array(Image.open('mask_heart.png'))

# Configure and generate the word cloud
wordcloud = WordCloud(
    width=1000,
    height=1000,
    background_color='white',
    mask=mask,
    stopwords=combined_stopwords,
    max_words=200,
    colormap='rainbow'
).generate(text)

# Display the generated word cloud
plt.figure(figsize=(10, 10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <hr/>

# %% [markdown]
# # Generating an Image with the Image API using Dall-E 3
# * Generated Sunday using the Image API's `'dall-e-3'` model
# > <img src="HavaneseDog.png" alt="Drawing" style="width: 300px;"/>

# %%
response = client.images.generate(
    model='dall-e-3',
    prompt="""Havanese dog as a japanese anime character  
              in neon colors against a black background""",
    quality='hd'
)

# %%
response
# Out:
# ImagesResponse(created=1733871248, data=[Image(b64_json=None, revised_prompt='Create an image of a Havanese dog personified as a Japanese anime character illustrated in striking neon colors like electrifying pinks, blues, and greens. The backdrop should be completely black to contrast and accentuate the vibrant neon colors.', url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-jYlbvdUr0yW0RbOwUCi7DLaz.png?st=2024-12-10T21%3A54%3A08Z&se=2024-12-10T23%3A54%3A08Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-10T21%3A22%3A40Z&ske=2024-12-11T21%3A22%3A40Z&sks=b&skv=2024-08-04&sig=x46FYMW04tmTDhjLP/KWkz7nIjsWkSOqPnQ5Bdca1wI%3D')])

# %%
response.data[0].url

# %%
IPython.display.Image(url=response.data[0].url)

# %%
response2 = client.images.generate(
    model='dall-e-3',
    prompt="""Havanese dog in the style of Vincent Van Gogh""",
    quality='hd'
)

# %%
response2
# Out:
# ImagesResponse(created=1733871281, data=[Image(b64_json=None, revised_prompt="A captivating image of a Havanese dog in the distinguished style of Vincent Van Gogh, a post-Impressionist painter known for his dramatic, emotional and vibrant use of colour. This piece captures the rich texture and warm hues that Van Gogh is famous for, in a portrayal of the dog. The dog stands alertly, its expressive eyes staring into the distance, maybe pondering about the world, while the wavy, soft fur is displayed in a palette of colour and texture akin to the artist's iconic 'Starry Night'. Imitate the use of oil paint to exude the raw intensity seen in Van Gogh's work.", url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-AToVseCrgKPlhK7QGF2Hb6bz.png?st=2024-12-10T21%3A54%3A41Z&se=2024-12-10T23%3A54%3A41Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-10T21%3A30%3A37Z&ske=2024-12-11T21%3A30%3A37Z&sks=b&skv=2024-08-04&sig=6f4ixntauwgvOEQ7t2w0Hjc%2BnyP4KkyQnlyl7mmT5Jw%3D')])

# %%
IPython.display.Image(url=response2.data[0].url)

# %%
response3 = client.images.generate(
    model='dall-e-3',
    prompt="""Havanese dog in the style of Leonardo DaVinci""",
    quality='hd'
)

# %%
response3
# Out:
# ImagesResponse(created=1733871292, data=[Image(b64_json=None, revised_prompt='A Havanese dog, richly detailed and possessing an air of serenity and charm typical of the High Renaissance period. Focus on capturing the essence of the dog as Leonardo Da Vinci might have done in one of his exquisite, ink-wash paintings.', url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-hU2xGT0m4Tsyuxsj6hSspWwy.png?st=2024-12-10T21%3A54%3A52Z&se=2024-12-10T23%3A54%3A52Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-10T21%3A40%3A14Z&ske=2024-12-11T21%3A40%3A14Z&sks=b&skv=2024-08-04&sig=qBQSmzS8fLY8lHJIWphm%2BtkrsGXky/GPPtN/NQ/UPCY%3D')])

# %%
IPython.display.Image(url=response3.data[0].url)

# %% [markdown]
# <hr/>

# %% [markdown]
# # Other Cool Stuff To Check Out
# * ChatGPT as a Data Analytics Tool ― https://mitsloanedtech.mit.edu/ai/tools/data-analysis/how-to-use-chatgpts-advanced-data-analysis-feature/
# * OpenAI Playground ― https://platform.openai.com/playground
# * 7 Best AI Art Generators ― https://www.techrepublic.com/article/best-ai-art-generators/
# * Top 20 ChatGPT Prompts For Software Developers ― https://www.geeksforgeeks.org/chatgpt-prompts-for-software-developers/
# * OpenAI Developer Forum ― https://community.openai.com/
# * Google Project Gemini ― https://blog.google/technology/ai/google-gemini-ai/
# * Vectorizer.ai — Converts generated images to vector graphics ― https://vectorizer.ai
# * "A Very Gentle Introduction to Large Language Models without the Hype" by Mark Riedl, Georgia Tech Professor ― https://mark-riedl.medium.com/a-very-gentle-introduction-to-large-language-models-without-the-hype-5f67941fa59e

# %% [markdown]
# <hr/>
# &copy; 2024 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com
