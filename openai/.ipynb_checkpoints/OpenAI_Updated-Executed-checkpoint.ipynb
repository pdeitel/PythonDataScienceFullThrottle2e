# %% [markdown]
# &copy; 2025 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com
#
# <hr/>

# %%
# %%html
# <style>
#     h1 {color:#BB0000}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>
# Out:
# <style>
#     h1 {color:#BB0000}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>

# %%
# enable high-res images in notebook 
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Importing the Modules for This Demo

# %%
from openai import OpenAI 
# from docx import Document # for creating a Microsoft Word docx file

# %% [markdown]
# ## Creating the `OpenAI` Client Object
# * Provides access to the OpenAI APIs

# %%
client = OpenAI()

# %% [markdown]
# * Assumes your API key is in the environment variable `OPENAI_API_KEY`
# * If you used a different environment variable name, replace with preceding statement with
# > `client = OpenAI(api_key=os.environ.get("CUSTOM_ENV_NAME"))`

# %% [markdown]
# # Text Summarization
# ## Summary Abstract

# %%
from pathlib import Path

path = Path('resources/transcript.txt')
transcript = path.read_text()

# Summary Abstract
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 
         'content': """Given a transcript of a technical presentation, create a 
             concise, clear summary abstract in paragraph form, written 
             in a direct style that avoids prepositional phrases and 
             uses straightforward sentence structures. Focus on the key 
             points without referring to the speaker. Capture the key 
             ideas, so that a person can understand it without reading the 
             full transcript."""},
        {'role': 'user', 'content': transcript}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The "What's New in Java" lesson introduces updates from Java versions 10 through 22, with a preview of a feature from Java 23. This lesson is part of new video content aimed at enhancing the Java Fundamentals third edition and other Java-centric educational resources. Key enhancements covered include executing Java source files directly, a simplified main method, and multi-line strings called text blocks from Java 11 onward. Java 14 offers more expressive switch expressions, and Java 16 introduces records for immutable data handling. Java 17 brings pseudo-random number generators, while Java 21 pushes forward with pattern matching for switch statements. Java 22 contributes unnamed variables and patterns, simplifying scenarios where variable names are not needed in code. Preview features like "Statements Before Super" permit validation before superclass constructor calls, potentially improving constructor efficiency. Sealed classes and interfaces introduced in Java 21 give developers hierarchal control by limiting subclassing and implementation. This lesson also addresses changes in sequenced collections, standardizing method names across collections to enhance accessibility and consistency. These updates aim to improve code simplicity, efficiency, and interactivity while maintaining consistency within the Java programming landscape.

# %% [markdown]
# ## Key Points

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 
         'content': """Given a transcript of a technical presentation,  
             identify the top 5 key points and present them as a numbered list.  
             For each point, use a concise, direct, clear, and
             straightforward sentence. Avoid prepositional phrases."""},
        {'role': 'user', 'content': transcript}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# 1. The course covers key Java programming features from Java 10 through Java 22, with a preview of a Java 23 feature.
#
# 2. The updated Java video course includes new examples and practical applications of Java's functionality, focusing on areas like control statements, data structures, and object-oriented programming.
#
# 3. New Java features include text blocks for handling multi-line strings, switch expressions for a more powerful and compact version of switch statements, and pattern matching enhancements.
#
# 4. The course introduces records, improved random number generation, and several updates for Java's concurrency capabilities, emphasizing modular, scalable programming practices.
#
# 5. The course material highlights Java's latest updates, like the simplification of the main method, JavaFX for graphical interfaces, and the new preview feature for Statements Before Super in subclass constructors.

# %% [markdown]
# # Sentiment Analysis

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 
         'content': """You are an expert in sentiment analysis. Analyze 
             the following presentation transcript and state whether
             the sentiment is positive, negative, or neutral.
             Explain your analysis."""},
        {'role': 'user', 'content': transcript}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The sentiment in this presentation transcript is neutral. The transcript is essentially a factual description of what the lesson will cover, specifically focusing on new features in Java and how they will be integrated into educational content. The speaker, Paul, provides a thorough overview of Java's updates and enhancements, explaining how they're relevant to different aspects of Java programming education. The overall tone is informational and instructional, aimed at giving an overview without expressing strong positive or negative emotions.
#
# Here are my reasons for determining the sentiment as neutral:
#
# 1. **Informational Content**: The transcript is heavily focused on detailing the features and updates in the Java programming language. It serves an educational purpose without displaying emotional language or personal opinions.
#
# 2. **Lack of Emotional Language**: There isn't any emotionally charged language such as "exciting," "fantastic," or "difficult," which would suggest a positive or negative sentiment. The speaker maintains an objective tone throughout.
#
# 3. **Neutral Topics**: Topics like version updates, lesson outlines, and programming language features are naturally neutral, as they are technical and matter-of-fact by nature.
#
# 4. **Purpose and Audience**: The context is a teaching session aimed at developers and learners interested in Java. The goal is to inform and educate rather than to persuade or evoke emotion.
#
# In conclusion, the transcript's intent is purely to present information about Java updates and how they will be incorporated into educational materials, which is typical of neutral sentiment.

# %% [markdown]
# # Image Descriptions

# %%
import base64

# %%
def describe_image(prompt, path_to_image):
    with open(path_to_image, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")
        
        return client.chat.completions.create(
            model='gpt-4o',
            messages=[
                {'role': 'system', 
                 'content': """You are an expert in sentiment analysis. Analyze 
                     the following presentation transcript and state whether
                     the sentiment is positive, negative, or neutral.
                     Explain your analysis."""},
                {'role': 'user',
                 'content': [
                    {'type': 'text', 'text': prompt},
                    {'type': 'image_url',
                     'image_url': {
                         'url': f"data:image/jpeg;base64,{base64_image}", 
                         'detail': 'high'}}]
                }
            ]
        )

# %% [markdown]
# ## Describe UML diagram
# ![ForLoop.png](attachment:12c22ad2-4b72-4d88-b1bd-b01268405fc1.png)

# %%
response = describe_image(
    """The attached image is a UML activity diagram showing the
    flow of control through a Java 'for' loop with UML 
    notes for additional context.""", 
    './resources/ForLoop.png')

# %%
print(response.choices[0].message.content)
# Out:
# The UML activity diagram illustrates the flow of control in a Java `for` loop. Here is a breakdown of the process depicted:
#
# 1. **Initialize Control Variable**: The loop begins with the initialization of a control variable, `int counter = 1`.
#
# 2. **Check Condition**: There's a decision point where the condition `[counter <= 10]` is evaluated.
#    - If true, the flow continues.
#    - If false, it moves to determining whether looping should continue (loop exits here as the condition is no longer met).
#
# 3. **Display the Counter Value**: If the condition is true, the counter value is displayed using `System.out.printf("%d ", counter);`.
#
# 4. **Increment the Control Variable**: The control variable is incremented using `++counter`.
#
# 5. **Loop Continuation**: After incrementing, the loop checks the condition again, repeating the cycle while the condition holds true.
#
# The loop executes from `counter = 1` to `counter = 10`, printing each value and incrementing until it exceeds 10.
#
# The diagram effectively captures the logic of a typical `for` loop, including initialization, condition checking, action within the loop, and incrementing, providing a visual representation of the loop's execution flow.

# %% [markdown]
# ## Describe a beach scene
# ![beach.jpg](attachment:4d865d06-e69f-4299-8bc8-cd04c55b6d93.jpg)

# %%
response = describe_image(
    """Describe in detail the attached photo of a beach scene,
    including every object in the photo.""", 
    './resources/beach.jpg')

# %%
print(response.choices[0].message.content)
# Out:
# The photo depicts a serene beach scene with the following elements:
#
# 1. **Sand**: The foreground is dominated by a stretch of light-colored sand, appearing clean and smooth.
#
# 2. **Palm Tree**: Centrally positioned is a tall palm tree with green and yellow fronds extending outward.
#
# 3. **Sun Loungers**: There are two white plastic sun loungers positioned on the sand. They are oriented facing the water, suggesting a relaxing view for sunbathers.
#
# 4. **Ocean and Boats**: The ocean forms the background, with a beautiful gradient from light turquoise near the shore to a deeper blue farther out. There are several boats visible in the water:
#     - A sailboat on the left with its mast up.
#     - A motorboat closer to the horizon.
#
# 5. **Sky**: The sky is predominantly clear with a few scattered clouds, casting a bright, sunny appearance across the scene.
#
# 6. **Pier with Building**: On the right, a wooden pier extends into the water, ending at a small building with a thatched roof.
#
# 7. **Beach Umbrella**: In the top right corner of the image, part of a beach umbrella or a thatched roof is visible, suggesting shaded seating.
#
# This beach scene conveys a tranquil and inviting atmosphere, perfect for relaxation and enjoying the ocean view.

# %% [markdown]
# # Text Translation

# %%
def translate(text, language):
    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system',
             'content': f"""You are an expert in natural language translation.
                 Translate the following text into {language}."""},
            {'role': 'user',
             'content': text}
        ]
    )

    return response.choices[0].message.content

# %%
english_text = "Today was a beautiful day. Tomorrow looks like bad weather."

# %% [markdown]
# ## Translate to Spanish and Japanese
# * Automatically figures out source language

# %%
spanish_text = translate(english_text, 'Spanish')
spanish_text
# Out:
# 'Hoy fue un día hermoso. Mañana parece que habrá mal tiempo.'

# %%
japanese_text = translate(english_text, 'Japanese')
japanese_text
# Out:
# '今日は美しい日でした。明日は悪天候になりそうです。'

# %% [markdown]
# ## Translate from Spanish and Japanese Back to English

# %%
translate(spanish_text, 'English')
# Out:
# 'Today was a beautiful day. Tomorrow it seems there will be bad weather.'

# %%
translate(japanese_text, 'English')
# Out:
# 'Today was a beautiful day. It seems like the weather will be bad tomorrow.'

# %% [markdown]
# # Code Generation

# %%
# Generate Python code with OpenAI API
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {'role': 'system', 
         'content': "You are an expert Python programmer."},
        {'role': 'user', 
         'content': """Write Python code that uses the word_cloud 
             Python library to generate a rainbow color word cloud from 
             the top 200 words in the file 'RomeoAndJuliet.txt' which 
             is in the current folder. Remove both modern English and 
             old English stop words. Use the mask image named mask_heart.png, 
             which is also in the current folder. 
             Display the generated word cloud."""}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# To generate a word cloud from the text file `RomeoAndJuliet.txt` while removing both modern and old English stop words, and using a mask image named `mask_heart.png`, you can use the `wordcloud` library along with `matplotlib` for displaying and `PIL` for image processing. Here's a step-by-step implementation:
#
# 1. Install the required packages if you haven't already. You can use the following commands in your terminal:
#    ```bash
#    pip install wordcloud
#    pip install matplotlib
#    pip install pillow
#    ```
#
# 2. Create a Python script to generate the word cloud. Here's the complete code:
#
# ```python
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud, STOPWORDS
# from PIL import Image
# import numpy as np
#
# # Load the text file
# text_file_path = 'RomeoAndJuliet.txt'
# with open(text_file_path, 'r', encoding='utf-8') as file:
#     text = file.read()
#
# # Define modern and old English stop words
# modern_stopwords = set(STOPWORDS)
# old_english_stopwords = {"thou", "thee", "thy", "dost", "hath", "art", "hast", "wilt",
#                          "shalt", "ye", "nay", "ere", "thine", "unto", "wouldst",
#                          "shouldst", "couldst", "wast"}
#
# # Combine the stop words
# combined_stopwords = modern_stopwords.union(old_english_stopwords)
#
# # Load the mask image
# mask_image_path = 'mask_heart.png'
# mask_image = np.array(Image.open(mask_image_path))
#
# # Create the word cloud
# wordcloud = WordCloud(width=800, height=800,
#                       background_color='white',
#                       stopwords=combined_stopwords,
#                       max_words=200,
#                       colormap='rainbow',
#                       mask=mask_image,
#                       contour_color='black',
#                       contour_width=1).generate(text)
#
# # Display the word cloud
# plt.figure(figsize=(8, 8), facecolor=None)
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.tight_layout(pad=0)
#
# plt.show()
# ```
#
# ### Key Points:
# - **STOPWORDS:** We utilize the built-in modern English stop words from the `wordcloud` library and extend them with a set of old English words.
# - **Mask Image:** The `mask_heart.png` image is read into a numpy array and used as the mask for shaping the word cloud.
# - **Colormap:** We use the 'rainbow' colormap to achieve the desired rainbow color effect.
# - **Disabling Axis:** The axis is turned off for a cleaner display of the word cloud.
# - **Contour:** A black contour is added around the word cloud for better shape definition.
#
# Make sure the `RomeoAndJuliet.txt` and `mask_heart.png` files are in the same directory as your script for the code to work properly. Run this script, and it will display the generated word cloud.

# %% [markdown]
# ## Try the code

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np

# Load the text file
text_file_path = 'RomeoAndJuliet.txt'
with open(text_file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define modern and old English stop words
modern_stopwords = set(STOPWORDS)
old_english_stopwords = {"thou", "thee", "thy", "dost", "hath", "art", "hast", "wilt", 
                         "shalt", "ye", "nay", "ere", "thine", "unto", "wouldst", 
                         "shouldst", "couldst", "wast"}

# Combine the stop words
combined_stopwords = modern_stopwords.union(old_english_stopwords)

# Load the mask image
mask_image_path = 'mask_heart.png'
mask_image = np.array(Image.open(mask_image_path))

# Create the word cloud
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      stopwords=combined_stopwords,
                      max_words=200,
                      colormap='rainbow',
                      mask=mask_image,
                      contour_color='black',
                      contour_width=1).generate(text)

# Display the word cloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# # Named Entity Recognition

# %%
import json

path = Path("resources/web.txt")
text = path.read_text()
text
# Out:
# 'The World Wide Web (simply called "the web") is a collection of hardware and software associated with the Internet that allows computer users to locate and view documents (with various combinations of text, graphics, animations, audios and videos) on almost any subject. In 1989, Tim Berners-Lee of CERN (the European Organization for Nuclear Research) began developing HyperText Markup Language (HTML)—the technology for sharing information via "hyperlinked" text documents. He also wrote communication protocols such as HyperText Transfer Protocol (HTTP) to form the backbone of his new hypertext information system, which he referred to as the World Wide Web. In 1994, Berners-Lee founded the World Wide Web Consortium (W3C, https://www.w3.org), which was devoted to developing web technologies. A key W3C goal is to make the web universally accessible to everyone regardless of disabilities, language or culture.'

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {'role': 'system', 
         'content': 
             """You are an expert in named entity recognition NER). 
             Analyze the user-supplied text and extract the named 
             entities. Return the result as a JSON object with the 
             following format:
             {
                "entities": [
                   {"text": "Entity name", "tag": "Entity type"}
                ]
             }
             Ensure the output is strictly in JSON format with 
             no additional text."""},
        {'role': 'user', 'content': text}
    ],
    response_format={"type": "json_object"}
)

json_response = json.loads(response.choices[0].message.content)

# %%
print(json.dumps(json_response, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "text": "World Wide Web",
#       "tag": "Organization"
#     },
#     {
#       "text": "Internet",
#       "tag": "Organization"
#     },
#     {
#       "text": "1989",
#       "tag": "Date"
#     },
#     {
#       "text": "Tim Berners-Lee",
#       "tag": "Person"
#     },
#     {
#       "text": "CERN",
#       "tag": "Organization"
#     },
#     {
#       "text": "European Organization for Nuclear Research",
#       "tag": "Organization"
#     },
#     {
#       "text": "HyperText Markup Language",
#       "tag": "Technology"
#     },
#     {
#       "text": "HTML",
#       "tag": "Technology"
#     },
#     {
#       "text": "HyperText Transfer Protocol",
#       "tag": "Technology"
#     },
#     {
#       "text": "HTTP",
#       "tag": "Technology"
#     },
#     {
#       "text": "1994",
#       "tag": "Date"
#     },
#     {
#       "text": "World Wide Web Consortium",
#       "tag": "Organization"
#     },
#     {
#       "text": "W3C",
#       "tag": "Organization"
#     },
#     {
#       "text": "https://www.w3.org",
#       "tag": "URL"
#     }
#   ]
# }

# %% [markdown]
# # Speech-to-Text

# %%
def speech_to_text(audio_path):
    with open(audio_path, 'rb') as audio_file:
        transcript = client.audio.transcriptions.create( 
            model='whisper-1', file=audio_file)
    return transcript.text

# %%
transcript = speech_to_text('resources/deep_learning_intro.m4a')

# %%
transcript
# Out:
# "So let's start with a little bit of an introduction to deep learning, which is a powerful subset of the machine learning capabilities that are available to us, not only in Python, but in other languages as well. Now, deep learning is particularly resource intensive because of the approach that it takes, but as you're about to see, whether you're a professional just getting into deep learning for the first time, or even a novice programmer, the libraries that we use, once again, are going to make it possible for us to start working with these supremely complex models behind the scenes. And one of the reasons that we're able to do that is because of the availability of things like big data, lots of processing power, whether it's on even our desktop computers, but mostly in the cloud nowadays, faster internet speeds to help us work with those processors and data in the cloud, and separately, advancements in parallel computing, both at the hardware and software levels. Now, the models that we're going to build in this lesson are much more sophisticated in terms of their setups and what's going on behind the scenes than the scikit-learn models that we started looking at in the preceding lesson. Typically, we're going to build our models by connecting together many layers, and one of the reasons it's called deep learning is that the more layers you have, the deeper the stack of layers is, and that's where the term deep learning comes from. Now, we'll be, again, working with this library called Keras, which is a friendly interface to the most popular of the deep learning libraries out there, Google's TensorFlow, and that is by far the most widely used of the deep learning libraries. But Keras was developed by a gentleman by the name of Francois Chollet from the Google Mind team, and his goal with Keras was to make deep learning easier and more accessible to everyone. So, if you are interested after looking through this lesson in pursuing deep learning more, I would highly recommend his book called Deep Learning with Python as well. And, by the way, Google alone has thousands of TensorFlow and Keras deep learning projects going on internally at the moment, and yearly, that number is increasing very quickly as well. Now, again, the deep learning models that we're going to be looking at are extremely complex. They require extensive mathematical backgrounds to understand their inner workings. We're not going to focus on mathematics at all in this presentation. Our goal is to show you how we can use Keras similarly to Scikit-learn, but in the context of deep learning. And what you're going to see is that the models we build are going to encapsulate all of that sophisticated mathematics that's going on behind the scenes. So, you will be able to build your own deep learning models even without understanding that mathematics. And, in fact, a little bit later on, I'm going to show you a quote from Francois Chollet about the fact that humans shouldn't be expected to understand the inner workings of certain aspects of these models because they are so complex. And if you think about it, you, on a daily basis as a programmer, are constantly relying on the work of other people to help you build applications, and you do it without questioning how those libraries that you're working with are constructed behind the scenes in most cases. So, the same thing is going on here. It's just a much more complex set of capabilities that are being implemented for you. And, really, you are standing on the shoulders of giants who have come before you to implement these incredibly complex model capabilities and allow you, as a programmer, to take advantage of them in your daily programming tasks. Now, the deep learning stuff that we're going to be doing does require significant processing power. The two examples we will present in this lesson, one of them takes five to six minutes on most of today's computers to train based on the 70,000 images that we'll be work ...

# %% [markdown]
# # Text-to-Speech

# %%
def text_to_speech(text, filename):
    response = client.audio.speech.create(
        model='tts-1-hd',
        voice='onyx',
        input=text
    )

    response.write_to_file(f'{filename}')

# %%
text_to_speech(english_text, './resources/outputs/english_speech.mp3')

# %%
text_to_speech(spanish_text, './resources/outputs/spanish_speech.mp3')

# %%
text_to_speech(japanese_text, './resources/outputs/japanese_speech.mp3')

# %%
import IPython
IPython.display.Audio(filename='./resources/outputs/english_speech.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
IPython.display.Audio(filename='./resources/outputs/spanish_speech.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
IPython.display.Audio(filename='./resources/outputs/japanese_speech.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Image Generation

# %%
def create_image(prompt):
    response = client.images.generate(
        model='dall-e-3',
        prompt=prompt,
        quality='hd'
    )
    return response.data[0].url

# %%
create_image(
    """Havanese dog as a Japanese anime character
    in neon colors against a black background""")
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-y0vTyaiQJrv9DgXxRAnbUOne.png?st=2025-03-04T13%3A52%3A00Z&se=2025-03-04T15%3A52%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-03-04T02%3A15%3A36Z&ske=2025-03-05T02%3A15%3A36Z&sks=b&skv=2024-08-04&sig=pwSy78jUUw/OfwDbwB93LPuatx2z3gqB91sHPykf89w%3D'

# %%
create_image('Havanese dog in the style of Vincent Van Gogh')
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-gNrhLWUeRrSjuruPfOcjBfnZ.png?st=2025-03-04T13%3A52%3A14Z&se=2025-03-04T15%3A52%3A14Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-03-04T02%3A20%3A48Z&ske=2025-03-05T02%3A20%3A48Z&sks=b&skv=2024-08-04&sig=vIrWS3/sSf48qW8bDAhr10LjTmLsnRxlCoRwVcYjoUc%3D'

# %%
create_image('Havanese dog in the style of Leonardo DaVinci')
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-8etU2WKhoZvdMZdacTaaRKzl/user-Oi1CdnYKcjhWjEniFrIJPjCV/img-1yjbmKAZJFZGWbyvPQf42ob8.png?st=2025-03-04T13%3A52%3A28Z&se=2025-03-04T15%3A52%3A28Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-03-04T02%3A29%3A09Z&ske=2025-03-05T02%3A29%3A09Z&sks=b&skv=2024-08-04&sig=jALr9qNV/osneZJUhTtW7597PQshEONtObBo/l9Ucdg%3D'

# %% [markdown]
# # Content Moderation

# %%
while True:
    prompt = input("\nEnter prompt (exit to terminate): ")
    
    if prompt.lower() == "exit":
        break

    response = client.moderations.create(input=prompt)
    result = response.results[0]

    if not result.flagged:
        print("Prompt not flagged for offensive content")
    else:
        print("Offensive content categories & scores:")
        
        for cat, flag, score in \
            zip(result.categories.__dict__.keys(),
                result.categories.__dict__.values(),
                result.category_scores.__dict__.values()):
            print(f"{cat if cat else 'None'}: {flag if flag else 'None'} {score if score else 0:.2f}")
# Out:
# Enter prompt (exit to terminate):  Have an awesome day!
# Prompt not flagged for offensive content
# Enter prompt (exit to terminate):  I will hurt them.
# Offensive content categories & scores:
# harassment: None 0.05
# harassment_threatening: None 0.09
# hate: None 0.01
# hate_threatening: None 0.00
# illicit: None 0.00
# illicit_violent: None 0.00
# self_harm: None 0.00
# self_harm_instructions: None 0.00
# self_harm_intent: None 0.00
# sexual: None 0.00
# sexual_minors: None 0.00
# violence: True 0.98
# violence_graphic: None 0.00
# Enter prompt (exit to terminate):  exit

# %% [markdown]
# <hr/>
# &copy; 2025 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com
