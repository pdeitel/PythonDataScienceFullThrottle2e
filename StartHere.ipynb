# %% [markdown]
# &copy; 2026 by Deitel & Associates, Inc. All Rights Reserved. The content in this notebook is based on the textbook [**Intro Python for Computer Science and Data Science**](https://amzn.to/2YU0QTJ) and our professional book [**Python for Programmers**](https://amzn.to/2VvdnxE) — Please do not purchase both. The professional book is a subset of the textbook.

# %%
# %%html
# <!-- CSS settings for this notbook -->
# <style>
#     h1 {color:#03A}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>
# Out:
# <!-- CSS settings for this notbook -->
# <style>
#     h1 {color:#03A}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>

# %% [markdown]
# <img src="./images/PythonDSAIFT.png" width="800" alt="Python Data Science and AI Full Throttle title slide"/>

# %% [markdown]
# <hr style="border: 0; height: 3px; background: #333; background-image: linear-gradient(to right, #ccc, black, #ccc);"/>

# %% [markdown]
# # About Me
# * CEO, Deitel & Associates, Inc.
# * MIT grad
# * 46 years in computing
# * One of the world’s most experienced programming languages trainers
#     * Teaching to industry, military and academic software developers worldwide since 1992
# * Among the world’s best-selling programming languages authors
#
# <hr style="border: 0; height: 3px; background: #333; background-image: linear-gradient(to right, #ccc, black, #ccc);"/>

# %% [markdown]
# # Staying in Touch
# <table style="width:100%; border-collapse:collapse; text-align:left; table-layout:auto; ">
#   <colgroup>
#     <col style="width: auto;">
#     <col style="width: auto;">
#   </colgroup>
#   <tr><td><strong>E-mail:</strong></td><td><a href="mailto:paul@deitel.com">paul@deitel.com</a></td></tr>
#   <tr><td><strong>Website:</strong></td><td><a href="https://deitel.com">https://deitel.com</a></td></tr>
#   <tr><td><strong>Contact us:</strong></td><td><a href="https://deitel.com/contact-us">https://deitel.com/contact-us</a></td></tr>
#   <tr><td><strong>Facebook:</strong></td><td><a href="https://facebook.com/DeitelFan">https://facebook.com/DeitelFan</a></td></tr>
#   <tr><td><strong>Threads:</strong></td><td><a href="https://threads.net/DeitelFan">https://threads.net/DeitelFan</a></td></tr>
#   <tr><td><strong>X:</strong></td><td><a href="https://x.com/deitel">https://x.com/deitel</a></td></tr>
#   <tr><td><strong>LinkedIn:</strong></td><td><a href="https://linkedin.com/company/deitel-&amp;-associates">https://linkedin.com/company/deitel-&amp;-associates</a></td></tr>
#   <tr><td><strong>Mastodon:</strong></td><td><a href="https://mastodon.social/@deitel">https://mastodon.social/@deitel</a></td></tr>
#   <tr><td><strong>BlueSky:</strong></td><td><a href="https://bsky.app/profile/deitel.bsky.social">https://bsky.app/profile/deitel.bsky.social</a></td></tr>
#   <tr><td><strong>YouTube:</strong></td><td><a href="https://youtube.com/DeitelTV">https://youtube.com/DeitelTV</a></td></tr>
# </table>
#
# ---

# %% [markdown]
# # My Upcoming O'Reilly Live Training Courses
# https://deitel.com/LearnWithDeitel
#
# | Date       | Title                                                                 |
# |:-----------|:----------------------------------------------------------------------|
# | May 5, 2026	| [Python Data Science and AI Full Throttle: Intro Data Science, Predictive AI and Generative AI Case Studies (new segment on programming with the OpenAI APIs)](https://learning.oreilly.com/live-events/python-data-science-ai-full-throttle-with-paul-deitel-introductory-ai-big-data-cloud-genai-case-studies/0642572313494/0642572313487/) |
# | May 12, 2026|  [Python Full Throttle](https://learning.oreilly.com/live-events/python-full-throttle-with-paul-deitel-a-one-day-fast-paced-code-intensive-python-presentation/0636920274667/) |
# | June 2, 2026	|  [Python Full Throttle](https://learning.oreilly.com/live-events/python-full-throttle-with-paul-deitel-a-one-day-fast-paced-code-intensive-python-presentation/0636920274667/) |
# | June 30, 2026	|  [**NEW! OpenAI’s Python APIs & Agents SDK: A Code-Intensive Intro!**](https://learning.oreilly.com/live-events/openais-python-apis-agents-sdk-a-code-intensive-intro-with-paul-deitel/0642572353476/0642572353469/) Using text, images, audio, code & moderation APIs, and the Agents SDK |
#
# ---

# %% [markdown]
# # Deitel Python on O'Reilly:<br/>https://deitel.com/LearnWithDeitel
# * **NEW EDITIONS UNDER DEVELOPMENT NOW**
#     * Updated Before You Begin, Lessons 1-6 and a **new genAI lesson** posted
# * Early access here on O'Reilly
# * Updating the videos in place in the current product at: https://learning.oreilly.com/api/v1/continue/9780135917411/
#
# <div style="float: left; padding-right:10px;text-align:center"><a href="https://learning.oreilly.com/videos/python-fundamentals/9780135917411"><img alt="Python Fundamentals LiveLessons cover" src="./images/PythonFundamentals2e.png" width="185" border="1"/></a></br>50+ hours of in-depth videos</div>
# <div style="float: left; padding-right:10px;text-align:center"><a href="https://learning.oreilly.com/library/view/intro-to-python/9780135404799/"><img alt="Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud" src="./images/IntroToPythonCover.png" width="195" border="1"></a><br/><a href="https://amzn.to/2LiDCmt">Buy on Amazon</a></div></div>
# <div style="float: left; padding-right:10px;text-align:center"><a href="https://learning.oreilly.com/library/view/python-for-programmers/9780135231364"><img alt="Python for Programmers cover" src="./images/PyFPCover.png" width="184" border="1"/></a><br/><a href="https://amzn.to/2VvdnxE">Buy on Amazon</a></div>

# %% [markdown]
# Please do not buy both books. **Python for Programmers** is a subset of **Intro to Python**.

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # [Our Python Textbook for College Courses](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/)
# <a style="float: left; padding-right:25px" href="https://amzn.to/2LiDCmt"><img alt="Intro to Python for Computer Science and Data Science: Learning to Program with AI, Big Data and the Cloud" src="./images/IntroToPythonCover.png" width="150" border="1"></a>
#
# * **College Professors/Instructors**:
# [Pre-Recorded Webinar Overview](https://www.pearson.com/us/about/news-events/events/2019/04/intro-to-python-for-computer-science-and-data-science.html).
# * [**Request an examination copy**](https://www.pearson.com/replocator) from your Pearson rep
# * Full color
# * 880 pages&mdash;240 more than **Python for Programmers**
# * **Programming fundamentals**, including **program development**
# * **557 self-check exercises**
# * **471 end-of-chapter exercises and projects**—Good for term projects, directed studies, capstone projects and thesis research topics across many fields
# * **More Info:**
# https://deitel.com/intro-to-python-for-computer-science-and-data-science/

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Java How to Program, 12/e and<br>Java for Programmers, 5/e
# <a style="float:left; padding-right:30px; width: 204px;" href="https://deitel.com/jhtp12"><img alt="Java How to Program, 12/e cover image" src="./images/jhtp12Cover.jpg" border="1"/></a>
#
# <a style="float:left; padding-right:30px; width: 200px;" href="https://deitel.com/javafp5"><img alt="Java for Programmers, 5/e cover image" src="./images/JavaFP5Cover.png" border="1"/></a>
#
# <a style="float:left; padding-right:30px; width: 200px;" href="https://learning.oreilly.com/course/java-fundamentals-with/9780135353134/"><img alt="Java Fundamentals, 3/e videos cover image" src="./images/java-fundamentals-3-e-videos.jpg" border="1"/></a>

# %% [markdown]
# * [**Java How to Program, 12/e**](https://deitel.com/jhtp12) (full-color e-books published, full-color print book coming soon)
# * [**Java for Programmers, 5/e** on O'Reilly](https://learning.oreilly.com/library/view/java-for-programmers/9780137574834/)
# * [**Java Fundamentals LiveLessons. 3/e** on O'Reilly](https://learning.oreilly.com/course/java-fundamentals-with/9780135353134/)
#     * 30 hours already posted
#     * Recording a new lesson on GenAI API-based Apps via the OpenAI APIs

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # **C++20 LiveLessons** and **C++20 for Programmers**<br/>https://deitel.com/LearnWithDeitel
# <a style="float:left; padding-right:30px; width: 200px;" href="https://learning.oreilly.com/videos/c20-fundamentals/9780136875185"><img alt="C++ Fundamentals LiveLessons cover" src="./images/cpp20ll.jpg" border="1"/></a>
#
# <a style="float:left; padding-right:10px; width:184px;" href="https://learning.oreilly.com/library/view/c20-for-programmers/9780136905776/"><img alt="C++20 for Programmers cover" src="https://deitel.com/wp-content/uploads/2022/01/c-plus-plus-20-for-programmers-cover.png" border="1"/></a>

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # C++ How to Program:<br>An Objects-Natural Approach, 11/e
#
# <a style="float:left; padding-right:30px; width: 200px;" href="https://deitel.com/cpphtp11"><img alt="C++ How to Program, 11/e cover" src="https://deitel.com/wp-content/uploads/2023/05/c-plus-plus-how-to-program-11-e-cover.png" border="1"/></a>
#
# * https://deitel.com/cpphtp11
# * One year more up-to-date than **C++20 for Programmers**
# * No more print textbooks
# * e-book formats: **Amazon Kindle** (and other e-readers), **https://VitalSource.com**, **https://RedShelf.com**
# * **Pearson+ eText** (includes VideoNotes for Chapters 1-10) — https://pearson.com
# * **Pearson Revel** (Pearson eText + VideoNotes for Chapters 1-10 + graded assessments) — https://revel.pearson.com

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # C How to Program, 9/e: with Application Programming<br>and Systems Programming Case Studies
# **E-mail paul@deitel.com** with questions.
#
# <a style="float: left; padding-right:30px" href="https://deitel.com/c-how-to-program-9-e/"><img alt="C How to Program, 9/e" src="https://deitel.com/wp-content/uploads/2021/02/c-how-to-program-9-e.jpg" width="200px" border="1"/></a>
#
# **A Few Key Features:**
# * Rich coverage of programming fundamentals
# * **20+ rich case studies from computer science, artificial intelligence, data science and other fields**
# * 350+ integrated self-check exercises with answers
# * Enhanced security/data science per ACM™/IEEE™ guidelines
# * Use free open-source libraries and tools
# * gnuplot visualization
# * raylib game programming
# * AI: Machine learning, natural language processing
# * Robotics and 3D graphics with the Webots simulator

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Code and Jupyter Notebooks for Today's Presentation
# * Presenting in **Jupyter Notebooks**
# * [**Download the notebooks** from my GitHub repository](https://github.com/pdeitel/PythonDataScienceFullThrottle2e)
# * Root **`PythonDataScienceFullThrottle2e`** folder contains this **`StartHere.ipynb`** and subfolders for the sections of today's presentation

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Note Regarding Code Execution
# * **Today's goal:** Expose you to **many data science and AI topics** in Python
# * Some **require complex software setups** that I can't cover in the course due to time constraints
# * I don't intend for you to run everything in parallel with my presentation, but I provided setup scripts in the GitHub repository's `install` folder along with a `README.md` file explaining how to use the scripts. These assume you've installed the [Anaconda Python Distribution](https://www.anaconda.com/download/success?reg=skipped).

# %% [markdown]
# <!-- # Docker
# These instructions assume you have Docker Desktop installed with support for the `docker compose` command
#
# From a **Terminal** window (Mac) or a **Command Prompt** or **Powershell** window (Windows) change to the root folder of the files you downloaded from my GitHub repository, then execute:
#
# > `docker compose up --pull always`
#
# This will pull my most recent version of the Docker container I use for this course, and you'll have access to the GitHub repository's files from the local folder on your computer.
#
# Once the container is running, you'll see a line of text similar to the following:
#
# > `http://127.0.0.1:8888/lab?token=fb59401a105a0c5a45c52eff8e1a8469f508cad1f3a8be06`
#
# Copy **your system's version of this line** and paste it into your preferred web browser to launch JupyterLab.
#
#
# Can also build a local container from the `Dockerfile` in the GitHub repository.
#
# These instructions assume you have Docker Desktop installed with support for the `docker compose` command and that you've downloaded or cloned this repository to your system. Comment out the `Dockerfile` line:
#
# > `COPY . /home/jovyan/`
# >
# by inserting a `#` before the line as in
#
# > `# COPY . /home/jovyan/`
#
# (or simply delete that line.)
# -->

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Multitiered Learning Approach
# * No need to take extensive notes.
# * A video of this presentation will be available 24 hours after the course.

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# ### Detailed Treatments of This Material
# Here on O'Reilly
# * **[_Python Fundamentals_ video training](https://learning.oreilly.com/videos/python-fundamentals/9780135917411)**
# * **[_Python for Programmers_ e-book](https://learning.oreilly.com/library/view/python-for-programmers/9780135231364/)**
# * **[_Intro to Python for Computer Science and Data Science_ e-book](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/)**

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Rhythm of the Course
# * **Whirlwind tour** of
#     * Natural Language Processing
#     * Data Mining
#     * Machine Learning (supervised and unsupervised)
#     * Deep learning
#     * Big Data: NoSQL, Spark and IoT
#     * Generative AI with the OpenAI APIs
# * **Lecture only, source-code focused presentation**
#     * Six lecture segments and 5 breaks
#     * Two 7-minute breaks in first half
#     * 30-minute meal break after approximately 3 hours
#     * Two 7-minute breaks in last half

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Need More Detail?
# * We **extensively indexed** [**Python for Programmers**](https://learning.oreilly.com/library/view/python-for-programmers/9780135231364/) here on O'Reilly
#     * Locating a topic in our book will help you locate its video presentation in my [**Python Fundamentals LiveLessons videos**](https://learning.oreilly.com/videos/python-fundamentals/9780135917411)
# * **Questions** after the course? **<paul@deitel.com>**

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # &nbsp;
# # &nbsp;
# # **"If I have seen further it is by standing on the shoulders of giants."** &mdash; Isaac Newton (and others before him)
# # &nbsp;
# # &nbsp;

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# &copy; 2026 by Deitel & Associates, Inc. All Rights Reserved. The content in this notebook is based on the textbook [**Intro Python for Computer Science and Data Science**](https://amzn.to/2YU0QTJ) and our professional book [**Python for Programmers**](https://amzn.to/2VvdnxE) — Please do not purchase both. The professional book is a subset of the textbook.
