# %% [markdown]
# ©️ Copyright 2026 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com

# %%
# %%html
# <!-- CSS settings for this notbook -->
# <style>
#     h1 {color:#03A}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>
# Out:
# <!-- CSS settings for this notbook -->
# <style>
#     h1 {color:#03A}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, #ccc, black, #ccc);
#     }
# </style>

# %% [markdown]
# # Handwritten Digit Classification Using<br>ChatGPT's Advanced Data Analytics (ADA) Mode
# Based on
# * Sections [15.2](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/xhtml/fileP7001016447000000000000000006786.xhtml) and [15.3](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/xhtml/fileP7001016447000000000000000006931.xhtml) of [Intro to Python for Computer Science and Data Science](https://learning.oreilly.com/library/view/intro-to-python/9780135404799) and
# * My video presentation in Lesson 14 of my [Python Fundamentals](https://learning.oreilly.com/videos/python-fundamentals-with/9780135917411/9780135917411-PFLL_Lesson14_00/) video course.

# %% [markdown]
# ---
#
# ## Overview
# This handout contrasts two ways to complete the digits computer-vision case study:
#
# 1. **Manual Workflow**
#
#     The case-study steps I presented and executed in class (plus several more from the case study in Sections [15.2](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/xhtml/fileP7001016447000000000000000006786.xhtml) and [15.3](https://learning.oreilly.com/library/view/intro-to-python/9780135404799/xhtml/fileP7001016447000000000000000006931.xhtml) of our textbook). You can perform each step in your own environment on your local computer or using a cloud-hosted environment.
#
# 2. **ChatGPT Advanced Data Analytics (ADA) Workflow**
#
#     You'll use ChatGPT's integrated Python environment for data analysis, which behaves like a persistent Jupyter notebook within ChatGPT. ADA mode allows you to delegate tasks to ChatGPT using natural-language instructions rather than writing code yourself. Once activated, ADA can
#     * write and execute Python code,
#     * load datasets,
#     * create visualizations,
#     * perform statistical analysis,
#     * run machine-learning models,
#     * inspect objects,
#     * summarize results, and
#     * explain concepts upon request.

# %% [markdown]
# ## How to Use This Document
# For each step from the digits case study I showed in class (plus a few I did not show), this handout provides prompts that direct ADA to replicate the manual step and explore deeper analytical questions.
#
# Each step contains:
#
# > **My Case Study Step:** <br>A brief summary of my case study's step.
#
# > **ADA Prompt:** <br>A prompt for ChatGPT to perform the step using ADA.
#
# For each step, copy the **ADA Prompt** and paste it into ChatGPT. Then, study its code, explanations and insights. After some steps, we provide optional prompts to help you learn more. ChatGPT sometimes suggests its own "next steps after it responds to prompts. These sometimes include steps listed later in this document.
#
# Optionally, you can create code cells in this notebook, paste in ChatGPT's generated code, and execute it locally.
#
# **ADA's usage limits vary** based on whether you're a free or paid user, the paid tier you subscribe to, and current demand.

# %% [markdown]
# ---

# %% [markdown]
# ## Activating Advanced Data Analytics (ADA) Mode
# Enable ADA mode with the following **ADA Prompt**:
# > You are my data analytics assistant. Use your Advanced Data Analytics mode for all computations. Keep all variables alive unless I say otherwise. Display the code you execute. Produce clear tables for results. Display visualizations when helpful. Provide explanations and insights after each result.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Load the Digits Dataset and Describe It
# **My Case Study Step:** <br>Import `load_digits`, load the dataset into a variable, and display its `DESCR` field to review the dataset description.
#
# **ADA Prompt:** <br>Load scikit-learn's bundled digits dataset, then summarize its main attributes and key characteristics.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Explore Data Arrays and View a Sample Image
#
# **My Case Study Step:** <br>Display `data` and `target` array shapes. Display a sample's 8×8 image and its target value.
#
# **ADA Prompt:** <br>Show me the shapes of this dataset's arrays. Then select one sample, display its 8×8 image, its label, and explain how the 8×8 pixels relate to the flattened feature vector. Show the grayscale pixels with 0 as white and 16 as black.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Visualize the First 24 Digit Images
# **My Case Study Step:** <br>Create a 4-by-6 grid of subplots, display the first 24 images, remove ticks, set grayscale, and label each image.
#
# **ADA Prompt:** <br>Display the first 24 digit images in a 4-by-6 grid, labeling each image with its target value.
#
# ### Learn More
# * **Term:** Sample Variation Visualization
# * **Definition:** Examining multiple samples from each class to observe natural variation.
# * **Explanation:** Highlights why certain digits are challenging to classify.
# * **Prompt:** <br>For each digit 0–9, display 10 randomly selected sample images in a small grid. Summarize the major variations within each class.

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Split the Data into Training and Testing Sets
#
# **My Case Study Step:** <br>Use `train_test_split` with `random_state=11` to generate the training and testing sets reproducibly.
#
# **ADA Prompt:** <br>Explain the ways to split the dataset for training and testing. Then use the best approach to split the dataset for classification models.

# %% [markdown]
# ---

# %% [markdown]
# # 5. Create and Train the k-Nearest Neighbors Classifier
#
# **My Case Study Step:** <br>Create a default `KNeighborsClassifier` and train it using `.fit()`.
#
# **ADA Prompt:** <br>Create a default `KNeighborsClassifier` and train it on the training data. Then explain what an estimator is and what a hyperparameter is in scikit-learn.
#
# ### Learn More
# * **Term:** *Hyperparameter*
# * **Definition:** User-defined configuration value that specified when you create an estimator.
# * **Explanation:** A setting you choose before training a model—such as k in k-NN—that configures how the learning algorithm behaves.
# * **Prompt:** <br>Explain the `KNeighborsClassifier`'s hyperparameters.

# %% [markdown]
# ---

# %% [markdown]
# # 6. Make Predictions and Compute Model Accuracy
#
# **My Case Study Step:** <br>Use `predict`, compare predictions against expected labels, identify misclassifications, and compute accuracy manually and via `score`.
#
# **ADA Prompt:** <br>Use the trained k-NN classifier to predict the test labels. Show the first few predictions beside their expected labels, highlight incorrect predictions, and compute the overall accuracy.
#
# ### Learn More
# * **Term:** *Misclassification Inspection*
# * **Definition:** Reviewing errors to understand the model's weaknesses.
# * **Explanation:** Misclassified samples reveal ambiguous cases.
# * **Prompt:** <br>Show the images that were misclassified and annotate them with their expected and predicted labels. Summarize any patterns in the errors.

# %% [markdown]
# ---

# %% [markdown]
# # 7. Evaluate the Classifier Using Metrics and Visualizations
#
# ### Part A
#
# **My Case Study Step:** <br>Create and analyze a confusion matrix. Examine correct predictions (diagonal) and errors (off-diagonal).
#
# **ADA Prompt:** <br>Generate a confusion matrix for the model's predictions. Explain how to interpret the rows, columns, and diagonal values.
#
# ### Part B
#
# **My Case Study Step:** <br>Create a classification report (precision, recall, f1-score, support) and a Seaborn heat map of the confusion matrix.
#
# **ADA Prompt:** <br>Generate a classification report. Explain what precision, recall, f1-score, and support represent.
#
#
# ### Learn More
# * **Term:** *Class Difficulty Analysis*
# * **Definition:** Determining which classes contribute most to model error.
# * **Explanation:** Similar-looking digits lead to higher confusion.
# * **Prompt:** <br>Identify the digits with the lowest recall and precision. Explain why these digits tend to be harder to classify."

# %% [markdown]
# ---

# %% [markdown]
# # 8. Perform K-Fold Cross-Validation
#
# **My Case Study Step:** <br>Use 10-fold cross-validation with shuffled data to compute multiple accuracy scores, then compute the mean and standard deviation.
#
# **ADA Prompt:** <br>Perform 10-fold cross-validation for the k-NN classifier. Show each fold’s accuracy, then compute the mean accuracy and standard deviation and explain the results.

# %% [markdown]
# ---

# %% [markdown]
# # 9. Compare Multiple Models
#
# **My Case Study Step:** <br>Create a dictionary of models and compare them using cross-validation to see which performs best.
#
# **ADA Prompt:** <br>Compare the scikit-learn classifiers k-NN, SVC, and Naive Bayes using the same cross-validation procedure. Summarize which models perform best and why.
#
# ### Learn More
# * **Term:** *Model Family Comparison*
# * **Definition:** Understanding differences among algorithm categories.
# * **Explanation:** Some models capture nonlinear patterns more effectively.
# * **Prompt:** <br>Try logistic regression and random forest classifiers and explain how their performance compares to the previous models.

# %% [markdown]
# ---

# %% [markdown]
# # 10. Hyperparameter Tuning for k in k-NN
#
# **My Case Study Step:** <br>Evaluate odd values of k from 1 to 19 using cross-validation, comparing mean accuracies.
#
# **ADA Prompt:** <br>Evaluate the k-NN classifier for odd values of k from 1 to 19 using cross-validation. Display the results and identify the best-performing k value.

# %% [markdown]
# ---

# %% [markdown]
# ## 11. Going Beyond the Original Case Study
# I'll discuss some of these items in the Deep Learning part of the presentation. **Note:** Some of these items may be too computationally intensive to complete in ChatGPT's free and Plus versions, but it should still generate code that you could run locally.

# %% [markdown]
# ---

# %% [markdown]
# ### 11.1 Feature Standardization
#
# * **Definition:** Scaling features so they have mean 0 and standard deviation 1.
# * **Explanation:** Essential for models that rely on distance, such as SVC.
# * **ADA Prompt:**
# Explain why standardizing this dataset's features benefits certain classifiers. Then build and evaluate a model that standardizes the data before training.

# %% [markdown]
# ---

# %% [markdown]
# ### 11.2 Principal Component Analysis (PCA)
#
# * **Definition:** A dimensionality-reduction technique that identifies directions of maximum variance.
# * **Explanation:** Reduces noise and can improve model efficiency.
# * **ADA Prompt:**
# Apply PCA to the digits dataset. Display the proportion of variance explained by each component and discuss how many components are needed to retain most of the information.

# %% [markdown]
# ---

# %% [markdown]
# ### 11.3 Pipelines
#
# * **Definition:** A tool for combining preprocessing steps and the model into a single workflow.
# * **Explanation:** Ensures preprocessing is applied consistently during training and cross-validation.
# * **ADA Prompt:**
# Build a pipeline that standardizes the digits dataset, applies PCA with the optimal number of components for this dataset, and trains a classifier. Explain why pipelines prevent data leakage.

# %% [markdown]
# ---

# %% [markdown]
# ### 11.4 GridSearchCV
#
# * **Definition:** Searches over combinations of hyperparameters using cross-validation.
# * **Explanation:** Helps identify optimal settings for models.
# * **ADA Prompt:**
# Use `GridSearchCV` to tune the hyperparameters of a pipeline that includes scaling, PCA, and k-NN, then repeat the process for SVC. Report the best parameters and accuracy for each and compare the tuned models.

# %% [markdown]
# ---

# %% [markdown]
# ### 11.5 Confusion Matrix Comparison
#
# * **Definition:** Comparing confusion matrices across models.
# * **Explanation:** Highlights which classes benefit most from improved models.
# * **ADA Prompt:** <br>Compare confusion matrices for the tuned k-NN and SVC models and their baseline models with default hyperparameters. Summarize which digit classes improved the most.

# %% [markdown]
# ---

# %% [markdown]
# ©️ Copyright 2026 by Deitel & Associates, Inc. All Rights Reserved. https://deitel.com
